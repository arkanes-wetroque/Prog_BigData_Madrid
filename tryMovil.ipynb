# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Ajout du fichier 
file2017 = 'Datas/VEHICULOS_PARQUE_MOVIL_2017.csv'
file2018 = 'Datas/VEHICULOS_PARQUE_MOVIL_2018.csv'
file2019 = 'Datas/VEHICULOS_PARQUE_MOVIL_2019.csv'
file2020 = 'Datas/VEHICULOS_PARQUE_MOVIL_2020.csv'
file2021 = 'Datas/VEHICULOS_PARQUE_MOVIL_2021.csv'

#Variables waiting the main function to be create on main page and called
d17 = pd.read_csv(file2017, delimiter=';')
d18 = pd.read_csv(file2018, delimiter=';')
d19 = pd.read_csv(file2019, delimiter=';')
d20 = pd.read_csv(file2020, delimiter=';')
d21 = pd.read_csv(file2021, delimiter=';')

# %%
d17 = d17.drop_duplicates()
d18 = d18.drop_duplicates()
d19 = d19.drop_duplicates()
d20 = d20.drop_duplicates()
d21 = d21.drop_duplicates()

# %%
def processTotal(file, date):
    datas = pd.read_csv(file, delimiter=';')
    datas.drop_duplicates()
    datas = datas.iloc[:, 0:7]
    datas.columns = ['Num', 'Area', 'Direction', 'Uso', 'Vehicule', 'Juridique','Energie']
    datas['Energie'] = datas['Energie'].replace(['EL�CTRICO','GASOLINA / HIBRIDO','EL�CTRICO / H�BRIDO'],['ELÉCTRICO','GASOLINA/HIBRIDO','ELÉCTRICO / HÍBRIDO'])
    datas['Energie'] = datas['Energie'].replace(['DIESEL '],['DIESEL'])
    datas['Date'] = date
    
    return datas


def fusionDF(df1, df2, df3, df4, df5):
    datas = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
    return datas

# %%
d17 = processTotal(file2017, '2017')
d18 = processTotal(file2018, '2018')
d19 = processTotal(file2019, '2019')
d20 = processTotal(file2020, '2020')
d21 = processTotal(file2021, '2021')




total = fusionDF(d17,d18,d19,d20,d21)
total.head()
# Out:
#     Num                                               Area  \
# 0  8182  AREA DE GOBIERNO DE SALUD,  SEGURIDAD Y EMERGE...
# 1  6343  AREA DE GOBIERNO DE SALUD,  SEGURIDAD Y EMERGE...
# 2  2771     AREA DE GOBIERNO DE MEDIO AMBIENTE Y MOVILIDAD
# 3  2825  AREA DE GOBIERNO DE SALUD,  SEGURIDAD Y EMERGE...
# 4  2035  AREA DE GOBIERNO DE SALUD,  SEGURIDAD Y EMERGE...
#
#                                         Direction             Uso    Vehicule  \
# 0             D.G. EMERGENCIAS Y PROTECCI�N CIVIL       OPERATIVO  AMBULANCIA
# 1                    D.G. DE LA POLICIA MUNICIPAL       OPERATIVO     TURISMO
# 2  D.G. DE GESTI�N Y VIGILANCIA DE LA CIRCULACI�N       OPERATIVO        MOTO
# 3                    D.G. DE LA POLICIA MUNICIPAL       OPERATIVO   FURGONETA
# 4       S.G.T. DE SALUD,  SEGURIDAD Y EMERGENCIAS  ADMINISTRATIVO     TURISMO
#
#    Juridique           Energie  Date
# 0    RENTING            DIESEL  2017
# 1    RENTING          GASOLINA  2017
# 2  PROPIEDAD          GASOLINA  2017
# 3  PROPIEDAD            DIESEL  2017
# 4    RENTING  GASOLINA/HIBRIDO  2017

# %%
group=total.groupby(["Energie", "Date"])['Num']
test = group.size().reset_index(name='counts')
test
# Out:
#                     Energie  Date  counts
# 0                    DIESEL  2017     868
# 1                    DIESEL  2018     725
# 2                    DIESEL  2019     693
# 3                    DIESEL  2020     674
# 4                 DIESEL     2021     679
# 5          DIESEL            2021       1
# 6                 ELÉCTRICO  2017      47
# 7                 ELÉCTRICO  2018     133
# 8                 ELÉCTRICO  2019     305
# 9                 ELÉCTRICO  2020     351
# 10                ELÉCTRICO  2021     368
# 11      ELÉCTRICO / HÍBRIDO  2019      29
# 12      ELÉCTRICO / HÍBRIDO  2020      29
# 13       ELÉCTRICO/GASOLINA  2021      40
# 14  GAS LICUADO DE PETROLEO  2021      21
# 15   GAS NATURAL COMPRIMIDO  2021     160
# 16                 GASOLINA  2017    1099
# 17                 GASOLINA  2018    1050
# 18                 GASOLINA  2019     793
# 19                 GASOLINA  2020     770
# 20                 GASOLINA  2021    1043
# 21           GASOLINA / GLP  2017      84
# 22           GASOLINA / GLP  2018       1
# 23           GASOLINA / GLP  2019      21
# 24           GASOLINA / GLP  2020      21
# 25             GASOLINA/GNC  2018       1
# 26         GASOLINA/HIBRIDO  2017      85
# 27         GASOLINA/HIBRIDO  2018      22
# 28         GASOLINA/HIBRIDO  2019     300
# 29         GASOLINA/HIBRIDO  2020     305
# 30                      GNC  2018     113
# 31                      GNC  2019     124
# 32                      GNC  2020     124
# 33               No precisa  2021       8
# 34                       R.  2017       7
# 35                       R.  2018       7
# 36                       R.  2019       8
# 37                       R.  2020       8
